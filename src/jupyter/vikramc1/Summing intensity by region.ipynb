# %% [markdown]
# # Summing intensity by region

# %% [markdown]
# ### We will download a sample brain and registration from the Boss

# %%
# %matplotlib inline

# %%
import intern
import json
import matplotlib as mpl
import matplotlib.pylab as plt
from intern.remote.boss import BossRemote
from intern.resource.boss.resource import *
import numpy as np

# %%
sampleColl = 'control9_to_ara'
sampleExp = '50um_reg'
annoChan =  'annotation_50um_lddmm_withoutOlfactoryBulb2017-10-04_1233'
sampleChan = 'control9_res3'
sampleCoord = 'control9_res3'
sampleRes = 0

# %%
rmt = BossRemote()

# %%
rawResource = rmt.get_project(ChannelResource(sampleChan, sampleColl, sampleExp, datatype='uint16'))
rawCoord = rmt.get_project(CoordinateFrameResource(sampleCoord))
x_range = [rawCoord.x_start, rawCoord.x_stop]
y_range = [rawCoord.y_start, rawCoord.y_stop]
z_range = [rawCoord.z_start, rawCoord.z_stop]
rawData = rmt.get_cutout(rawResource, 0, x_range, y_range, z_range)

# %%
plt.imshow(rawData[:,:,150], cmap='gray')

# %%
annoResource = rmt.get_project(ChannelResource(annoChan, sampleColl, sampleExp, datatype='uint16'))
annoCoord = rmt.get_project(CoordinateFrameResource(sampleCoord))
x_range = [annoCoord.x_start, annoCoord.x_stop]
y_range = [annoCoord.y_start, annoCoord.y_stop]
z_range = [annoCoord.z_start, annoCoord.z_stop]
annoData = rmt.get_cutout(annoResource, 0, x_range, y_range, z_range)

# %%
plt.imshow(annoData[:,:,150], vmax=1000)

# %% [markdown]
# ### Now sum the intensity by region in the ARA

# %%
id2intensity = {}
for i in np.unique(annoData):
    idx = np.where(annoData == i)
    id2intensity[i] = np.sum(rawData[idx])
# verify that sums match the total sum in image
assert(np.sum(id2intensity.values()) == np.sum(rawData))

# %% [markdown]
# ## Getting names of regions from ARA ontology

# %%
def getChildren(node, id2name):
    id2name[node['id']] = node['name']
    # base case
    if node['children'] == []:
        return id2name
    # other case
    for i in range(len(node['children'])):
        id2name = getChildren(node['children'][i], id2name)
    return id2name

# %%
# load ara ontology file
f = json.load(file('ara_structure_ontology_wo_msg.json'))[0]

# %%
id2name = getChildren(f, {})

# %%
id2name[0] = 'background'

# %%
id2name
# Out:
# {0: 'background',
#  1: u'Tuberomammillary nucleus, ventral part',
#  2: u'Primary somatosensory area, mouth, layer 6b',
#  3: u'secondary fissure',
#  4: u'Inferior colliculus',
#  6: u'internal capsule',
#  7: u'Principal sensory nucleus of the trigeminal',
#  8: u'Basic cell groups and regions',
#  9: u'Primary somatosensory area, trunk, layer 6a',
#  10: u'Superior colliculus, motor related, intermediate gray layer',
#  11: u'posterolateral fissure',
#  12: u'Interfascicular nucleus raphe',
#  10707: u'Lingula (I), molecular layer',
#  15: u'Parataenial nucleus',
#  16: u'Layer 6b, isocortex',
#  17: u'Superior colliculus, motor related, intermediate white layer',
#  18: u'nodular fissure',
#  19: u'Induseum griseum',
#  20: u'Entorhinal area, lateral part, layer 2',
#  21: u'lateral olfactory tract, general',
#  22: u'Posterior parietal association areas',
#  23: u'Anterior amygdalar area',
#  25: u'simple fissure',
#  26: u'Superior colliculus, motor related, deep gray layer',
#  27: u'Intergeniculate leaflet of the lateral geniculate complex',
#  28: u'Entorhinal area, lateral part, layer 6a',
#  29: u'lateral spinothalamic tract',
#  30: u'Periventricular hypothalamic nucleus, anterior part',
#  31: u'Anterior cingulate area',
#  33: u'Primary visual area, layer 6a',
#  34: u'intercrural fissure',
#  35: u'Oculomotor nucleus',
#  36: u'Gustatory areas, layer 1',
#  37: u'longitudinal association bundle',
#  38: u'Paraventricular hypothalamic nucleus',
#  39: u'Anterior cingulate area, dorsal part',
#  41: u'posteromedial visual area, layer 2/3',
#  42: u'Superior colliculus, motor related, deep white layer',
#  43: u'ansoparamedian fissure',
#  44: u'Infralimbic area',
#  45: u'Spinal nucleus of the trigeminal, oral part, rostral dorsomedial part',
#  46: u'mammillary related',
#  47: u'Paraventricular hypothalamic nucleus, magnocellular division, anterior magnocellular part',
#  48: u'Anterior cingulate area, ventral part',
#  49: u'intraparafloccular fissure',
#  50: u'Precommissural nucleus',
#  51: u'Intralaminar nuclei of the dorsal thalamus',
#  52: u'Entorhinal area, lateral part, layer 3',
#  53: u'Spinal nucleus of the trigeminal, oral part, middle dorsomedial part, dorsal zone',
#  54: u'medial forebrain bundle',
#  55: u'Paraventricular hypothalamic nucleus, parvicellular division, anterior parvicellular part',
#  56: u'Nucleus accumbens',
#  57: u'paramedian sulcus',
#  58: u'Medial terminal nucleus of the accessory optic tract',
#  59: u'Intermediodorsal nucleus of the thalamus',
#  60: u'Entorhinal area, lateral part, layer 6b',
#  61: u'Spinal nucleus of the trigeminal, oral part, middle dorsomedial part, ventral zone',
#  62: u'medial longitudinal fascicle',
#  63: u'Paraventricular hypothalamic nucleus, descending division',
#  64: u'Anterodorsal nucleus',
#  65: u'parafloccular sulcus',
#  66: u'Lateral terminal nucleus of the accessory optic tract',
#  67: u'Interstitial nucleus of Cajal',
#  68: u'Frontal pole, layer 1',
#  69: u'Spinal nucleus of the trigeminal, oral part, ventrolateral part',
#  70: u'midbrain related',
#  71: u'Paraventricular hypothalamic nucleus, magnocellular division',
#  72: u'Anterodorsal preoptic nucleus',
#  73: u'ventricular systems',
#  74: u'Lateral visual area, layer 6a',
#  75: u'Dorsal terminal nucleus of the accessory optic tract',
#  76: u'Interstitial nucleus of the vestibular nerve',
#  77: u'Spinal nucleus of the trigeminal, oral part, caudal dorsomedial part',
#  78: u'middle cerebellar peduncle',
#  79: u'Paraventricular hypothalamic nucleus, magnocellular division, medial magnocellular part',
#  80: u'Anterior hypothalamic area',
#  81: u'lateral ventricle',
#  82: u'Nucleus of the lateral lemniscus, dorsal part',
#  83: u'Inferior olivary complex',
#  84: u'Prelimbic area, layer 6a',
#  85: u'spinocerebellar tract',
#  86: u'middle thalamic commissure',
#  87: u'Paraventricular hypothalamic nucleus, parvicellular division, medial parvicellular part, dorsal zone',
#  88: u'Anterior hypothalamic nucleus',
#  89: u'rhinocele',
#  90: u'Nucleus of the lateral lemniscus, horizontal part',
#  91: u'Interposed nucleus',
#  92: u'Entorhinal area, lateral part, layer 4',
#  93: u'motor root of the trigeminal nerve',
#  94: u'Paraventricular hypothalamic nucleus, parvicellular division',
#  95: u'Agranular insular area',
#  96: u'Dorsal cochlear nucleus',
#  97: u'Temporal association areas, layer 1',
#  98: u'subependymal zone',
#  99: u'Nucleus of the lateral lemniscus, ventral part',
#  100: u'Interpeduncular nucleus',
#  101: u'Ventral cochlear nucleus',
#  102: u'nigrostriatal tract',
#  103: u'Paraventricular hypothalamic nucleus, magnocellular division, posterior magnocellular part',
#  104: u'Agranular insular area, dorsal part',
#  105: u'Superior olivary complex, medial part',
#  106: u'Inferior salivatory nucleus',
#  107: u'Somatomotor areas, Layer 1',
#  108: u'choroid plexus',
#  109: u'nigrothalamic fibers',
#  110: u'Paraventricular hypothalamic nucleus, parvicellular division, periventricular part',
#  111: u'Agranular insular area, posterior part',
#  112: u'Granular lamina of the cochlear nuclei',
#  113: u'Primary somatosensory area, lower limb, layer 2/3',
#  114: u'Superior olivary complex, lateral part',
#  115: u'Trochlear nucleus',
#  116: u'choroid fissure',
#  117: u'optic chiasm',
#  118: u'Periventricular hypothalamic nucleus, intermediate part',
#  119: u'Agranular insular area, ventral part',
#  120: u'Agranular insular area, posterior part, layer 1',
#  121: u'Lateral visual area, layer 6b',
#  122: u'Superior olivary complex, periolivary region',
#  123: u'Koelliker-Fuse subnucleus',
#  124: u'interventricular foramen',
#  125: u'optic tract',
#  126: u'Periventricular hypothalamic nucleus, posterior part',
#  127: u'Anteromedial nucleus',
#  128: u'Midbrain reticular nucleus',
#  129: u'third ventricle',
#  130: u'Superior central nucleus raphe, medial part',
#  131: u'Lateral amygdalar nucleus',
#  132: u'Prelimbic area, layer 6b',
#  133: u'Periventricular hypothalamic nucleus, preoptic part',
#  134: u'pallidotegmental fascicle',
#  135: u'Nucleus ambiguus',
#  136: u'Intermediate reticular nucleus',
#  137: u'Superior central nucleus raphe, lateral part',
#  138: u'Lateral group of the dorsal thalamus',
#  139: u'Entorhinal area, lateral part, layer 5',
#  140: u'cerebral aqueduct',
#  141: u'Periventricular region',
#  142: u'pallidothalamic pathway',
#  143: u'Nucleus ambiguus, ventral division',
#  144: u'Olfactory tubercle, layers 1-3',
#  710: u'abducens nerve',
#  146: u'Pontine reticular nucleus',
#  12995: u'Somatosensory areas, layer 4',
#  148: u'Gustatory areas, layer 4',
#  149: u'Paraventricular nucleus of the thalamus',
#  150: u'periventricular bundle of the hypothalamus',
#  151: u'Accessory olfactory bulb',
#  152: u'Piriform area, layers 1-3',
#  708: u'Anterior hypothalamic nucleus, central part',
#  154: u'Perihypoglossal nuclei',
#  155: u'Lateral dorsal nucleus of thalamus',
#  156: u'Dorsal auditory area, layer 6a',
#  157: u'Periventricular zone',
#  158: u'posterior commissure',
#  159: u'Anterior olfactory nucleus',
#  160: u'Anterior olfactory nucleus, layer 1',
#  161: u'Nucleus intercalatus',
#  162: u'Laterodorsal tegmental nucleus',
#  163: u'Agranular insular area, posterior part, layer 2/3',
#  10712: u'Lobule III, Purkinje layer',
#  165: u'Midbrain raphe nuclei',
#  14: u'internal medullary lamina of the thalamus',
#  167: u'Anterior olfactory nucleus, dorsal part',
#  168: u'Anterior olfactory nucleus, layer 2',
#  169: u'Nucleus prepositus',
#  170: u'Dorsal part of the lateral geniculate complex',
#  171: u'Prelimbic area, layer 1',
#  173: u'Retrochiasmatic area',
#  174: u'preoptic commissure',
#  175: u'Anterior olfactory nucleus, external part',
#  177: u'Nucleus of Roller',
#  178: u'Ventral part of the lateral geniculate complex',
#  179: u'Anterior cingulate area, layer 6a',
#  180: u'Gustatory areas, layer 2/3',
#  181: u'Nucleus of reuniens',
#  182: u'propriohypothalamic pathways',
#  183: u'Anterior olfactory nucleus, lateral part',
#  184: u'Frontal pole, cerebral cortex',
#  185: u'Parapyramidal nucleus, deep part',
#  186: u'Lateral habenula',
#  187: u'Gustatory areas, layer 5',
#  188: u'Accessory olfactory bulb, glomerular layer',
#  189: u'Rhomboid nucleus',
#  190: u'pyramid',
#  191: u'Anterior olfactory nucleus, medial part',
#  192: u'Cortical amygdalar area, anterior part, layer 1',
#  193: u'Parapyramidal nucleus, superficial part',
#  194: u'Lateral hypothalamic area',
#  195: u'Prelimbic area, layer 2',
#  196: u'Accessory olfactory bulb, granular layer',
#  197: u'Rostral linear nucleus raphe',
#  198: u'pyramidal decussation',
#  199: u'Anterior olfactory nucleus, posteroventral part',
#  200: u'Cortical amygdalar area, anterior part, layer 2',
#  201: u'Primary somatosensory area, barrel field, layer 2/3',
#  202: u'Medial vestibular nucleus',
#  203: u'Linear nucleus of the medulla',
#  204: u'Accessory olfactory bulb, mitral layer',
#  205: u'retriculospinal tract, lateral part',
#  206: u'Nucleus raphe magnus',
#  207: u'Area postrema',
#  208: u'Cortical amygdalar area, anterior part, layer 3',
#  209: u'Lateral vestibular nucleus',
#  210: u'Lateral mammillary nucleus',
#  211: u'Anterior cingulate area, dorsal part, layer 2/3',
#  212: u'Main olfactory bulb, glomerular layer',
#  213: u'retriculospinal tract, medial part',
#  214: u'Red nucleus',
#  215: u'Anterior pretectal nucleus',
#  216: u'Cortical amygdalar area, posterior part, lateral zone, layer 1',
#  689: u'Ventrolateral preoptic nucleus',
#  218: u'Lateral posterior nucleus of the thalamus',
#  219: u'Somatomotor areas, Layer 2/3',
#  220: u'Main olfactory bulb, granule layer',
#  221: u'rubroreticular tract',
#  222: u'Nucleus raphe obscurus',
#  223: u'Arcuate hypothalamic nucleus',
#  224: u'Cortical amygdalar area, posterior part, lateral zone, layer 2',
#  225: u'Spinal vestibular nucleus',
#  226: u'Lateral preoptic area',
#  227: u'Anterior cingulate area, layer 6b',
#  228: u'Main olfactory bulb, inner plexiform layer',
#  229: u'sensory root of the trigeminal nerve',
#  230: u'Nucleus raphe pallidus',
#  231: u'Anterior tegmental nucleus',
#  232: u'Cortical amygdalar area, posterior part, lateral zone, layer 3',
#  233: u'Anterolateral visual area, layer 5',
#  234: u'Temporal association areas, layer 4',
#  235: u'Lateral reticular nucleus',
#  236: u'Main olfactory bulb, mitral layer',
#  312782546: u'Anterior area',
#  238: u'Nucleus raphe pontis',
#  239: u'Anterior group of the dorsal thalamus',
#  240: u'Cortical amygdalar area, posterior part, medial zone, layer 1',
#  241: u'Posterior parietal association areas, layer 2/3',
#  242: u'Lateral septal nucleus',
#  243: u'Dorsal auditory area, layer 6b',
#  244: u'Main olfactory bulb, outer plexiform layer',
#  245: u'spinocervical tract',
#  246: u'Midbrain reticular nucleus, retrorubral area',
#  247: u'Auditory areas',
#  248: u'Cortical amygdalar area, posterior part, medial zone, layer 2',
#  249: u'Posterior auditory area, layer 6a',
#  250: u'Lateral septal nucleus, caudal (caudodorsal) part',
#  251: u'Primary auditory area, layer 2/3',
#  252: u'Dorsal auditory area, layer 5',
#  253: u'spinohypothalamic pathway',
#  254: u'Retrosplenial area',
#  255: u'Anteroventral nucleus of thalamus',
#  256: u'Cortical amygdalar area, posterior part, medial zone, layer 3',
#  257: u'posteromedial visual area, layer 6a',
#  258: u'Lateral septal nucleus, rostral (rostroventral) part',
#  259: u'Entorhinal area, medial part, ventral zone, layer 1',
#  260: u'Nucleus of the lateral olfactory tract, molecular layer',
#  312782550: u'Anterior area, layer 1',
#  262: u'Reticular nucleus of the thalamus',
#  263: u'Anteroventral preoptic nucleus',
#  264: u'Orbital area, layer 1',
#  779: u'propriohypothalamic pathways, medial',
#  266: u'Lateral septal nucleus, ventral part',
#  267: u'Dorsal peduncular area, layer 6a',
#  268: u'Nucleus of the lateral olfactory tract, pyramidal layer',
#  269: u'Posterolateral visual area, layer 2/3',
#  270: u'spinoreticular pathway',
#  271: u'Nucleus sagulum',
#  272: u'Anteroventral periventricular nucleus',
#  728: u'arbor vitae',
#  274: u'Retrosplenial area, dorsal part, layer 6a',
#  275: u'Lateral septal complex',
#  276: u'Piriform area, molecular layer',
#  277: u'spinotectal pathway',
#  278: u'Striatum-like amygdalar nuclei',
#  279: u'Retrosplenial area, lateral agranular part, layer 6b',
#  280: u"Barrington's nucleus",
#  281: u'Anteromedial visual area, layer 1',
#  283: u'Lateral tegmental nucleus',
#  284: u'Piriform area, pyramidal layer',
#  312782554: u'Anterior area, layer 2/3',
#  286: u'Suprachiasmatic nucleus',
#  287: u'Bed nucleus of the anterior commissure',
#  288: u'Orbital area, ventrolateral part, layer 2/3',
#  289: u'Temporal association areas, layer 5',
#  290: u'Hypothalamic lateral zone',
#  291: u'Piriform area, polymorph layer',
#  292: u'Bed nucleus of the accessory olfactory tract',
#  293: u'spinovestibular pathway',
#  294: u'Superior colliculus, motor related',
#  295: u'Basolateral amygdalar nucleus',
#  296: u'Anterior cingulate area, ventral part, layer 2/3',
#  297: u'Taenia tecta, dorsal part, layers 1-4',
#  298: u'Magnocellular nucleus',
#  299: u'Somatomotor areas, Layer 5',
#  300: u'Ventral part of the lateral geniculate complex, lateral zone',
#  411: u'Medial amygdalar nucleus, anterodorsal part',
#  302: u'Superior colliculus, sensory related',
#  303: u'Basolateral amygdalar nucleus, anterior part',
#  304: u'Prelimbic area, layer 2/3',
#  305: u'Primary visual area, layer 6b',
#  306: u'Taenia tecta, ventral part, layers 1-3',
#  307: u'Magnocellular reticular nucleus',
#  308: u'Posterior parietal association areas, layer 6a',
#  312782558: u'Anterior area, layer 4',
#  310: u'Septofimbrial nucleus',
#  311: u'Basolateral amygdalar nucleus, posterior part',
#  312: u'Entorhinal area, lateral part, layer 4/5',
#  313: u'Midbrain',
#  314: u'Agranular insular area, posterior part, layer 6a',
#  315: u'Isocortex',
#  316: u'Ventral part of the lateral geniculate complex, medial zone',
#  317: u'subthalamic fascicle',
#  318: u'Supragenual nucleus',
#  319: u'Basomedial amygdalar nucleus',
#  320: u'Primary motor area, Layer 1',
#  321: u'Subgeniculate nucleus',
#  322: u'Primary somatosensory area',
#  323: u'Midbrain, motor related',
#  324: u'Entorhinal area, medial part, ventral zone, layer 2',
#  325: u'Suprageniculate nucleus',
#  326: u'superior cerebelar peduncles',
#  327: u'Basomedial amygdalar nucleus, anterior part',
#  328: u'Agranular insular area, dorsal part, layer 2/3',
#  329: u'Primary somatosensory area, barrel field',
#  330: u'Retrosplenial area, dorsal part, layer 6b',
#  331: u'Mammillary body',
#  332: u'Accessory supraoptic group',
#  312782562: u'Anterior area, layer 5',
#  334: u'Basomedial amygdalar nucleus, posterior part',
#  335: u'Perirhinal area, layer 6a',
#  336: u'superior colliculus commissure',
#  337: u'Primary somatosensory area, lower limb',
#  338: u'Subfornical organ',
#  339: u'Midbrain, sensory related',
#  340: u'Posterior parietal association areas, layer 6b',
#  341: u'supramammillary decussation',
#  342: u'Substantia innominata',
#  343: u'Brain stem',
#  344: u'Agranular insular area, posterior part, layer 5',
#  345: u'Primary somatosensory area, mouth',
#  346: u'Primary somatosensory area, layer 2/3',
#  347: u'Subparaventricular zone',
#  348: u'Midbrain, behavioral state related',
#  349: u'supraoptic commissures',
#  350: u'Subceruleus nucleus',
#  351: u'Bed nuclei of the stria terminalis',
#  352: u'Orbital area, layer 5',
#  353: u'Primary somatosensory area, nose',
#  354: u'Medulla',
#  355: u'Agranular insular area, posterior part, layer 6b',
#  356: u'Preparasubthalamic nucleus',
#  312782566: u'Anterior area, layer 6a',
#  358: u'Sublaterodorsal nucleus',
#  359: u'Bed nuclei of the stria terminalis, anterior division',
#  360: u'Dorsal peduncular area, layer 2/3',
#  361: u'Primary somatosensory area, trunk',
#  362: u'Mediodorsal nucleus of thalamus',
#  363: u'Prelimbic area, layer 5',
#  364: u'Parasubthalamic nucleus',
#  365: u'thalamic peduncles',
#  366: u'Submedial nucleus of the thalamus',
#  367: u'Bed nuclei of the stria terminalis, posterior division',
#  368: u'Perirhinal area, layer 6b',
#  369: u'Primary somatosensory area, upper limb',
#  370: u'Medulla, motor related',
#  371: u'Entorhinal area, medial part, ventral zone, layer 3',
#  372: u'Infracerebellar nucleus',
#  373: u'trigeminocerebellar tract',
#  374: u'Substantia nigra, compact part',
#  375: u"Ammon's horn",
#  376: u'Cortical amygdalar area, posterior part, lateral zone, layers 1-3',
#  377: u'Posterolateral visual area, layer 6a',
#  378: u'Supplemental somatosensory area',
#  379: u'Medulla, behavioral state related',
#  380: u'cuneate fascicle',
#  312782570: u'Anterior area, layer 6b',
#  382: u'Field CA1',
#  383: u'Cortical amygdalar area, posterior part, medial zone, layers 1-3',
#  384: u'trochlear nerve decussation',
#  385: u'Primary visual area',
#  386: u'Medulla, sensory related',
#  387: u'Entorhinal area, lateral part, layer 5/6',
#  357: u'tectothalamic pathway',
#  389: u'ventral spinothalamic tract',
#  390: u'Supraoptic nucleus',
#  391: u'Field CA1, stratum lacunosum-moleculare',
#  392: u'Nucleus of the lateral olfactory tract, layers 1-3',
#  393: u'Posterolateral visual area, layer 6b',
#  394: u'Anteromedial visual area',
#  395: u'Medullary reticular nucleus',
#  396: u'internal arcuate fibers',
#  397: u'ventral tegmental decussation',
#  398: u'Superior olivary complex',
#  399: u'Field CA1, stratum oriens',
#  400: u'Piriform-amygdalar area, layers 1-3',
#  401: u'Anteromedial visual area, layer 4',
#  402: u'Anterolateral visual area',
#  403: u'Medial amygdalar nucleus',
#  404: u'olivocerebellar tract',
#  312782574: u'Laterointermediate area',
#  406: u'Subparafascicular nucleus',
#  407: u'Field CA1, pyramidal layer',
#  408: u'Piriform-amygdalar area, molecular layer',
#  409: u'Lateral visual area',
#  410: u'reticulocerebellar tract',
#  484682479: u'Prosubiculum, dorsal part, molecular layer',
#  412: u'Orbital area, lateral part, layer 2/3',
#  413: u'vestibular nerve',
#  414: u'Subparafascicular nucleus, magnocellular part',
#  415: u'Field CA1, stratum radiatum',
#  416: u'Piriform-amygdalar area, pyramidal layer',
#  417: u'Rostrolateral visual area',
#  418: u'Medial amygdalar nucleus, anteroventral part',
#  419: u'Entorhinal area, medial part, ventral zone, layer 4',
#  420: u'precommissural fornix diagonal band',
#  421: u'Lateral visual area, layer 1',
#  422: u'Subparafascicular nucleus, parvicellular part',
#  423: u'Field CA2',
#  424: u'Piriform-amygdalar area, polymorph layer',
#  425: u'Posterolateral visual area',
#  426: u'Medial amygdalar nucleus, posterodorsal part',
#  427: u'Ectorhinal area/Layer 2/3',
#  428: u'medial corticohypothalamic tract',
#  480149234: u'Laterolateral anterior visual area, layer 1',
#  430: u'Retrosplenial area, ventral part, layer 2/3',
#  431: u'Field CA2, stratum lacunosum-moleculare',
#  432: u'Nucleus circularis',
#  433: u'Anteromedial visual area, layer 5',
#  434: u'Retrosplenial area, dorsal part, layer 2/3',
#  484682483: u'Prosubiculum, dorsal part, pyramidal layer',
#  10676: u'Crus 1, Purkinje layer',
#  437: u'Spinal nucleus of the trigeminal, interpolar part',
#  438: u'Field CA2, stratum oriens',
#  439: u'Paraventricular hypothalamic nucleus, descending division, dorsal parvicellular part',
#  440: u'Orbital area, lateral part, layer 6a',
#  441: u'Anteromedial visual area, layer 6b',
#  442: u'Retrosplenial area, dorsal part, layer 1',
#  10683: u'Paramedian lobule, molecular layer',
#  444: u'Medial group of the dorsal thalamus',
#  445: u'Spinal nucleus of the trigeminal, oral part',
#  446: u'Field CA2, pyramidal layer',
#  447: u'Paraventricular hypothalamic nucleus, descending division, forniceal part',
#  448: u'Orbital area, lateral part, layer 1',
#  10689: u'Paraflocculus, molecular layer',
#  450: u'Primary somatosensory area, upper limb, layer 1',
#  451: u'Basolateral amygdalar nucleus, ventral part',
#  452: u'Median preoptic nucleus',
#  312782582: u'Laterointermediate area, layer 2/3',
#  454: u'Field CA2, stratum radiatum',
#  10695: u'Parasubiculum, layer 3',
#  456: u'Posterior auditory area, layer 6b',
#  457: u'Visual areas, layer 6a',
#  10698: u'Postsubiculum, layer 3',
#  10699: u'Presubiculum, layer 1',
#  10700: u'Presubiculum, layer 2',
#  461: u'Primary somatosensory area, trunk, layer 6b',
#  10702: u'Dentate gyrus, subgranular zone',
#  463: u'Field CA3',
#  10704: u'Dentate gyrus, polymorph layer',
#  465: u'Olfactory tubercle, pyramidal layer',
#  10706: u'Lingula (I), Purkinje layer',
#  467: u'Hypothalamic medial zone',
#  468: u'Entorhinal area, medial part, dorsal zone, layer 2a',
#  469: u'posteromedial visual area, layer 6b',
#  470: u'Subthalamic nucleus',
#  471: u'Field CA3, stratum lacunosum-moleculare',
#  472: u'Medial amygdalar nucleus, posterodorsal part, sublayer a',
#  473: u'Olfactory tubercle, polymorph layer',
#  10714: u'Lobule IV, granular layer',
#  475: u'Medial geniculate complex',
#  476: u'Orbital area, layer 6a',
#  312782586: u'Laterointermediate area, layer 4',
#  478: u'Primary somatosensory area, lower limb, layer 6a',
#  479: u'Field CA3, stratum lucidum',
#  480: u'Medial amygdalar nucleus, posterodorsal part, sublayer b',
#  481: u'Islands of Calleja',
#  10722: u'Lobules IV-V, molecular layer',
#  483: u'Medial habenula',
#  484: u'Orbital area, medial part, layer 1',
#  485: u'Striatum dorsal region',
#  486: u'Field CA3, stratum oriens',
#  1105: u'Intercalated amygdalar nucleus',
#  488: u'Orbital area, lateral part, layer 6b',
#  484682492: u'Prosubiculum, ventral part',
#  10730: u'Pyramus (VIII), Purkinje layer',
#  491: u'Medial mammillary nucleus',
#  492: u'Orbital area, layer 2/3',
#  493: u'Striatum ventral region',
#  494: u'Superior colliculus, motor related, intermediate gray layer, sublayer a',
#  495: u'Field CA3, pyramidal layer',
#  496: u'Dorsal peduncular area, layer 1',
#  497: u'Visual areas, layer 6b',
#  498: u'Bed nuclei of the stria terminalis, anterior division, anteromedial area',
#  499: u'cuneocerebellar tract',
#  500: u'Somatomotor areas',
#  312782590: u'Laterointermediate area, layer 5',
#  502: u'Subiculum',
#  503: u'Superior colliculus, motor related, intermediate gray layer, sublayer b',
#  504: u'Field CA3, stratum radiatum',
#  505: u'Bed nuclei of the stria terminalis, anterior division, dorsomedial nucleus',
#  506: u'dorsal acoustic stria',
#  507: u'Main olfactory bulb',
#  508: u'Entorhinal area, medial part, dorsal zone, layer 2b',
#  509: u'Subiculum, dorsal part',
#  510: u'Primary somatosensory area, lower limb, layer 6b',
#  511: u'Superior colliculus, motor related, intermediate gray layer, sublayer c',
#  512: u'Cerebellum',
#  513: u'Bed nuclei of the stria terminalis, anterior division, fusiform nucleus',
#  514: u'dorsal column',
#  515: u'Medial preoptic nucleus',
#  516: u'Orbital area, layer 6b',
#  517: u'Postpiriform transition area, layers 1-3',
#  518: u'Subiculum, ventral part',
#  519: u'Cerebellar nuclei',
#  520: u'Ventral auditory area, layer 6a',
#  521: u'Bed nuclei of the stria terminalis, anterior division, magnocellular nucleus',
#  522: u'dorsal commissure of the spinal cord',
#  523: u'Medial preoptic area',
#  524: u'Orbital area, medial part, layer 2',
#  480149250: u'Laterolateral anterior visual area, layer 6a',
#  526: u'Entorhinal area, medial part, dorsal zone, layer 1',
#  527: u'Dorsal auditory area, layer 1',
#  528: u'Cerebellar cortex',
#  529: u'Bed nuclei of the stria terminalis, anterior division, ventral nucleus',
#  530: u'dorsal fornix',
#  531: u'Medial pretectal area',
#  532: u'Posterior parietal association areas, layer 1',
#  533: u'posteromedial visual area',
#  534: u'Supratrigeminal nucleus',
#  535: u'Dorsal peduncular area, layer 2',
#  536: u'Central amygdalar nucleus',
#  484682500: u'Prosubiculum, ventral part, pyramidal layer',
#  538: u'dorsal limb',
#  10671: u'Median eminence',
#  540: u'Perirhinal area, layer 1',
#  541: u'Temporal association areas',
#  542: u'Retrosplenial area, ventral part, layer 1',
#  543: u'Entorhinal area, medial part, dorsal zone, layer 2',
#  544: u'Central amygdalar nucleus, capsular part',
#  545: u'Retrosplenial area, dorsal part, layer 4',
#  546: u'Bed nuclei of the stria terminalis, anterior division, juxtacapsular nucleus',
#  547: u'dorsal longitudinal fascicle',
#  548: u'Midbrain reticular nucleus, magnocellular part, general',
#  480149254: u'Laterolateral anterior visual area, layer 6b',
#  550: u'Entorhinal area, medial part, dorsal zone, layer 5/6',
#  551: u'Central amygdalar nucleus, lateral part',
#  552: u'Pontine reticular nucleus, ventral part',
#  553: u'dorsal spinocerebellar tract',
#  554: u'Bed nuclei of the stria terminalis, anterior division, oval nucleus',
#  555: u'Midbrain reticular nucleus, parvicellular part',
#  556: u'Infralimbic area, layer 2/3',
#  557: u'Tuberomammillary nucleus',
#  558: u'Primary somatosensory area, nose, layer 1',
#  559: u'Central amygdalar nucleus, medial part',
#  560: u'Cochlear nucleus, subpedunclular granular region',
#  561: u'Visual areas, layer 2/3',
#  562: u'Bed nuclei of the stria terminalis, anterior division, rhomboid nucleus',
#  435: u'Medial amygdalar nucleus, posteroventral part',
#  564: u'Medial septal nucleus',
#  565: u'posteromedial visual area, layer 5',
#  566: u'Postpiriform transition area',
#  567: u'Cerebrum',
#  568: u'Accessory abducens nucleus',
#  569: u'Bed nuclei of the stria terminalis, posterior division, dorsal nucleus',
#  570: u'dorsolateral fascicle',
#  571: u'Midline group of the dorsal thalamus',
#  572: u'Anterior cingulate area, layer 1',
#  573: u'Lateral visual area, layer 4',
#  574: u'Tegmental reticular nucleus',
#  575: u'Central lateral nucleus of the thalamus',
#  496345664: u'Dorsal part of the lateral geniculate complex, shell',
#  577: u'Primary somatosensory area, upper limb, layer 4',
#  578: u'Bed nuclei of the stria terminalis, posterior division, principal nucleus',
#  579: u'external capsule',
#  496345668: u'Dorsal part of the lateral geniculate complex, core',
#  581: u'Triangular nucleus of septum',
#  582: u'Orbital area, medial part, layer 2/3',
#  583: u'Claustrum',
#  584: u'Cortical amygdalar area, posterior part, lateral zone, layers 1-2',
#  780: u'Posterior amygdalar nucleus',
#  586: u'fasciculus proprius',
#  587: u'Nucleus of Darkschewitsch',
#  588: u'Anterior cingulate area, ventral part, layer 1',
#  589: u'Taenia tecta',
#  590: u'Retrosplenial area, ventral part, layer 6a',
#  591: u'Central linear nucleus raphe',
#  592: u'Cortical amygdalar area, posterior part, medial zone, layers 1-2',
#  593: u'Primary visual area, layer 1',
#  594: u'Bed nuclei of the stria terminalis, posterior division, transverse nucleus',
#  713: u'perforant path',
#  596: u'Diagonal band nucleus',
#  597: u'Taenia tecta, dorsal part',
#  598: u'Ventral auditory area, layer 6b',
#  599: u'Central medial nucleus of the thalamus',
#  600: u'Dorsal auditory area, layer 2/3',
#  601: u'Anterolateral visual area, layer 6a',
#  602: u'Bed nuclei of the stria terminalis, posterior division, strial extension',
#  603: u'fimbria',
#  604: u'Nucleus incertus',
#  605: u'Taenia tecta, ventral part',
#  606: u'Retrosplenial area, ventral part, layer 2',
#  607: u'Cochlear nuclei',
#  608: u'Orbital area, ventrolateral part, layer 6a',
#  609: u'Subparafascicular area',
#  610: u'Retrosplenial area, dorsal part, layer 5',
#  443: u'dorsal hippocampal commissure',
#  612: u'Nucleus of the lateral lemniscus',
#  613: u'Lateral visual area, layer 5',
#  614: u'Tuberal nucleus',
#  615: u'Substantia nigra, lateral part',
#  616: u'Cuneiform nucleus',
#  617: u'Mediodorsal nucleus of the thalamus, central part',
#  618: u'hippocampal commissures',
#  619: u'Nucleus of the lateral olfactory tract',
#  620: u'Orbital area, medial part, layer 5',
#  621: u'Motor nucleus of trigeminal',
#  622: u'Retrosplenial area, ventral part, layer 6b',
#  623: u'Cerebral nuclei',
#  624: u'Interpeduncular fossa',
#  625: u'Primary somatosensory area, upper limb, layer 5',
#  626: u'Mediodorsal nucleus of the thalamus, lateral part',
#  627: u'hypothalamohypophysial tract',
#  628: u'Nucleus of the optic tract',
#  10697: u'Postsubiculum, layer 2',
#  630: u'Orbital area, lateral part, layer 5',
#  631: u'Cortical amygdalar area',
#  632: u'Dentate gyrus, granule cell layer',
#  633: u'inferior colliculus commissure',
#  634: u'Nucleus of the posterior commissure',
#  635: u'Posterior parietal association areas, layer 4',
#  636: u'Mediodorsal nucleus of the thalamus, medial part',
#  637: u'Ventral group of the dorsal thalamus',
#  638: u'Gustatory areas, layer 6a',
#  639: u'Cortical amygdalar area, anterior part',
#  640: u'Efferent vestibular nucleus',
#  10688: u'Paraflocculus, Purkinje layer',
#  642: u'Nucleus of the trapezoid body',
#  643: u'Posterior auditory area, layer 2/3',
#  644: u'Somatomotor areas, Layer 6a',
#  645: u'Vermal regions',
#  646: u'Dorsal peduncular area, layer 5',
#  647: u'Cortical amygdalar area, posterior part',
#  648: u'Primary motor area, Layer 5',
#  649: u'Anterolateral visual area, layer 6b',
#  650: u'juxtarestiform body',
#  651: u'Nucleus of the solitary tract',
#  652: u'Paraventricular hypothalamic nucleus, magnocellular division, posterior magnocellular part, lateral zone',
#  653: u'Abducens nucleus',
#  654: u'Primary somatosensory area, nose, layer 4',
#  655: u'Cortical amygdalar area, posterior part, lateral zone',
#  656: u'Secondary motor area, layer 1',
#  657: u'Primary somatosensory area, mouth, layer 2/3',
#  658: u'lateral lemniscus',
#  659: u'Nucleus of the solitary tract, central part',
#  660: u'Paraventricular hypothalamic nucleus, magnocellular division, posterior magnocellular part, medial zone',
#  661: u'Facial motor nucleus',
#  662: u'Gustatory areas, layer 6b',
#  663: u'Cortical amygdalar area, posterior part, medial zone',
#  664: u'Entorhinal area, medial part, dorsal zone, layer 3',
#  10692: u'Flocculus, molecular layer',
#  666: u'Nucleus of the solitary tract, commissural part',
#  667: u'Frontal pole, layer 2/3',
#  668: u'Dorsomedial nucleus of the hypothalamus, anterior part',
#  669: u'Visual areas',
#  670: u'Primary somatosensory area, trunk, layer 2/3',
#  671: u'Retrosplenial area, lateral agranular part, layer 1',
#  672: u'Caudoputamen',
#  673: u'mammillary peduncle',
#  674: u'Nucleus of the solitary tract, gelatinous part',
#  675: u'Agranular insular area, ventral part, layer 6a',
#  676: u'Dorsomedial nucleus of the hypothalamus, posterior part',
#  677: u'Visceral area',
#  678: u'Dorsal auditory area, layer 4',
#  679: u'Superior central nucleus raphe',
#  680: u'Orbital area, ventrolateral part, layer 6b',
#  484682524: u'auditory radiation',
#  682: u'Nucleus of the solitary tract, lateral part',
#  683: u'Posterior parietal association areas, layer 5',
#  684: u'Dorsomedial nucleus of the hypothalamus, ventral part',
#  685: u'Ventral medial nucleus of the thalamus',
#  686: u'Primary somatosensory area, layer 6a',
#  687: u'Retrosplenial area, ventral part, layer 5',
#  688: u'Cerebral cortex',
#  10696: u'Postsubiculum, layer 1',
#  10675: u'Crus 1, granular layer',
#  691: u'Nucleus of the solitary tract, medial part',
#  692: u'Perirhinal area, layer 5',
#  693: u'Ventromedial hypothalamic nucleus',
#  694: u'Agranular insular area, ventral part, layer 2/3',
#  695: u'Cortical plate',
#  696: u'Posterior auditory area, layer 1',
#  697: u'medial lemniscus',
#  698: u'Olfactory areas',
#  699: u'Agranular insular area, ventral part, layer 6b',
#  700: u'Anterior hypothalamic nucleus, anterior part',
#  458: u'Olfactory tubercle, molecular layer',
#  702: u'Primary somatosensory area, nose, layer 5',
#  703: u'Cortical subplate',
#  704: u'Agranular insular area, ventral part, layer 1',
#  12993: u'Somatosensory areas, layer 1',
#  12994: u'Somatosensory areas, layer 2/3',
#  707: u'Infralimbic area, layer 1',
#  12996: u'Somatosensory areas, layer 5',
#  12997: u'Somatosensory areas, layer 6a',
#  12998: u'Somatosensory areas, layer 6b',
#  711: u'Cuneate nucleus',
#  712: u'Entorhinal area, medial part, dorsal zone, layer 4',
#  460: u'Midbrain trigeminal nucleus',
#  714: u'Orbital area',
#  501: u'posteromedial visual area, layer 4',
#  716: u'Anterior hypothalamic nucleus, dorsal part',
#  717: u'accessory spinal nerve',
#  718: u'Ventral posterolateral nucleus of the thalamus',
#  719: u'Primary somatosensory area, layer 6b',
#  720: u'Dorsal column nuclei',
#  721: u'Primary visual area, layer 4',
#  722: u'periventricular bundle of the thalamus',
#  723: u'Orbital area, lateral part',
#  724: u'Anterior hypothalamic nucleus, posterior part',
#  725: u'Ventral posterolateral nucleus of the thalamus, parvicellular part',
#  726: u'Dentate gyrus',
#  727: u'Entorhinal area, medial part, dorsal zone, layer 5',
#  706: u'Olivary pretectal nucleus',
#  729: u'Temporal association areas, layer 6a',
#  730: u'pineal stalk',
#  731: u'Orbital area, medial part',
#  732: u'Medial mammillary nucleus, median part',
#  733: u'Ventral posteromedial nucleus of the thalamus',
#  734: u'Dentate gyrus crest',
#  735: u'Primary auditory area, layer 1',
#  736: u'central tegmental bundle',
#  464: u'Paraventricular hypothalamic nucleus, descending division, medial parvicellular part, ventral zone',
#  738: u'Orbital area, ventral part',
#  739: u'Anterior cingulate area, layer 5',
#  740: u'Medial preoptic nucleus, central part',
#  741: u'Ventral posteromedial nucleus of the thalamus, parvicellular part',
#  742: u'Dentate gyrus crest, molecular layer',
#  743: u'Entorhinal area, medial part, dorsal zone, layer 6',
#  744: u'cerebellar commissure',
#  745: u'precommissural fornix, general',
#  746: u'Orbital area, ventrolateral part',
#  747: u'Infralimbic area, layer 2',
#  748: u'Medial preoptic nucleus, lateral part',
#  749: u'Ventral tegmental area',
#  750: u'Posterolateral visual area, layer 1',
#  751: u'Dentate gyrus crest, polymorph layer',
#  752: u'cerebellar peduncles',
#  753: u'principal mammillary tract',
#  754: u'Olfactory tubercle',
#  755: u'Ventral auditory area, layer 2/3',
#  756: u'Medial preoptic nucleus, medial part',
#  757: u'Ventral tegmental nucleus',
#  758: u'Dentate gyrus crest, granule cell layer',
#  759: u'Posterior auditory area, layer 4',
#  760: u'cerebral nuclei related',
#  761: u'Ventromedial hypothalamic nucleus, anterior part',
#  762: u'propriohypothalamic pathways, dorsal',
#  763: u'Vascular organ of the lamina terminalis',
#  764: u'Entorhinal area, lateral part, layer 2b',
#  765: u'Nucleus x',
#  766: u'Dentate gyrus lateral blade',
#  767: u'Secondary motor area, layer 5',
#  484682496: u'Prosubiculum, ventral part, molecular layer',
#  769: u'Ventromedial hypothalamic nucleus, central part',
#  770: u'propriohypothalamic pathways, lateral',
#  771: u'Pons',
#  772: u'Anterior cingulate area, ventral part, layer 5',
#  773: u'Hypoglossal nucleus',
#  774: u'Retrosplenial area, lateral agranular part, layer 5',
#  775: u'Dentate gyrus lateral blade, molecular layer',
#  484682504: u'Prosubiculum, ventral part, stratum radiatum',
#  777: u'Ventromedial hypothalamic nucleus, dorsomedial part',
#  778: u'Primary visual area, layer 5',
#  10711: u'Lobule III, granular layer',
#  484682508: u'Area prostriata',
#  781: u'Nucleus y',
#  782: u'Dentate gyrus lateral blade, polymorph layer',
#  783: u'Agranular insular area, dorsal part, layer 6a',
#  484682512: u'supra-callosal cerebral white matter',
#  785: u'Ventromedial hypothalamic nucleus, ventrolateral part',
#  786: u'Temporal association areas, layer 6b',
#  787: u'propriohypothalamic pathways, ventral',
#  788: u'Piriform-amygdalar area',
#  789: u'Nucleus z',
#  790: u'Dentate gyrus lateral blade, granule cell layer',
#  791: u'Posterior auditory area, layer 5',
#  792: u'dorsal roots',
#  793: u'Primary somatosensory area, layer 1',
#  794: u'spinal tract of the trigeminal nerve',
#  795: u'Periaqueductal gray',
#  796: u'Dopaminergic A13 group',
#  797: u'Zona incerta',
#  798: u'facial nerve',
#  799: u'Dentate gyrus medial blade',
#  800: u'Agranular insular area, ventral part, layer 5',
#  801: u'Visual areas, layer 1',
#  802: u'stria medullaris',
#  803: u'Pallidum',
#  804: u'Fields of Forel',
#  805: u'posteromedial visual area, layer 1',
#  806: u'Supplemental somatosensory area, layer 2/3',
#  807: u'Dentate gyrus medial blade, molecular layer',
#  808: u'glossopharyngeal nerve',
#  809: u'Pallidum, caudal region',
#  810: u'Anterior cingulate area, ventral part, 6a',
#  811: u'Inferior colliculus, central nucleus',
#  812: u'superior cerebellar peduncle decussation',
#  813: u'hypoglossal nerve',
#  814: u'Dorsal peduncular area',
#  815: u'Dentate gyrus medial blade, polymorph layer',
#  816: u'Primary auditory area, layer 4',
#  817: u'supraoptic commissures, anterior',
#  818: u'Pallidum, dorsal region',
#  819: u'Anterior cingulate area, ventral part, 6b',
#  820: u'Inferior colliculus, dorsal nucleus',
#  821: u'Primary visual area, layer 2/3',
#  822: u'Retrohippocampal region',
#  823: u'Dentate gyrus medial blade, granule cell layer',
#  824: u'hypothalamus related',
#  825: u'supraoptic commissures, dorsal',
#  826: u'Pallidum, medial region',
#  827: u'Infralimbic area, layer 5',
#  828: u'Inferior colliculus, external nucleus',
#  829: u'Subiculum, dorsal part, molecular layer',
#  830: u'Dorsomedial nucleus of the hypothalamus',
#  831: u'Agranular insular area, dorsal part, layer 6b',
#  832: u'oculomotor nerve',
#  10720: u'Lobules IV-V, granular layer',
#  834: u'Superior colliculus, zonal layer',
#  835: u'Pallidum, ventral region',
#  836: u'Ectorhinal area/Layer 1',
#  837: u'Subiculum, dorsal part, stratum radiatum',
#  838: u'Primary somatosensory area, nose, layer 2/3',
#  839: u'Dorsal motor nucleus of the vagus nerve',
#  840: u'olfactory nerve',
#  841: u'trapezoid body',
#  842: u'Superior colliculus, superficial gray layer',
#  843: u'Parasubiculum',
#  844: u'Primary motor area, Layer 6a',
#  845: u'Subiculum, dorsal part, pyramidal layer',
#  846: u'Dentate nucleus',
#  847: u'Primary auditory area, layer 5',
#  848: u'optic nerve',
#  849: u'Visceral area, layer 6b',
#  850: u'uncinate fascicle',
#  851: u'Superior colliculus, optic layer',
#  852: u'Parvicellular reticular nucleus',
#  853: u'Subiculum, ventral part, molecular layer',
#  854: u'Primary somatosensory area, upper limb, layer 2/3',
#  10735: u'Nodulus (X), granular layer',
#  856: u'Thalamus, polymodal association cortex related',
#  857: u'Visceral area, layer 6a',
#  858: u'ventral commissure of the spinal cord',
#  859: u'Parasolitary nucleus',
#  860: u'Parabrachial nucleus, lateral division, central lateral part',
#  861: u'Subiculum, ventral part, stratum radiatum',
#  862: u'Supplemental somatosensory area, layer 6a',
#  10725: u'Declive (VI), molecular layer',
#  864: u'Thalamus, sensory-motor cortex related',
#  865: u'Primary somatosensory area, layer 4',
#  866: u'ventral spinocerebellar tract',
#  867: u'Parabrachial nucleus',
#  868: u'Parabrachial nucleus, lateral division, dorsal lateral part',
#  869: u'Posterolateral visual area, layer 4',
#  870: u'Subiculum, ventral part, pyramidal layer',
#  871: u'spinothalamic tract',
#  872: u'Dorsal nucleus raphe',
#  873: u'Supplemental somatosensory area, layer 1',
#  874: u'Parabigeminal nucleus',
#  487: u'Medial amygdalar nucleus, posterodorsal part, sublayer c',
#  876: u'accessory optic tract',
#  877: u'tectospinal pathway',
#  878: u'Primary somatosensory area, mouth, layer 1',
#  879: u'Retrosplenial area, dorsal part',
#  880: u'Dorsal tegmental nucleus',
#  881: u'Parabrachial nucleus, lateral division',
#  882: u'Primary motor area, Layer 6b',
#  883: u'Parabrachial nucleus, lateral division, superior lateral part',
#  884: u'amygdalar capsule',
#  10736: u'Nodulus (X), Purkinje layer',
#  886: u'Retrosplenial area, ventral part',
#  489: u'Major island of Calleja',
#  888: u'Perirhinal area, layer 2/3',
#  889: u'Primary somatosensory area, nose, layer 6a',
#  890: u'Parabrachial nucleus, medial division',
#  891: u'Parabrachial nucleus, lateral division, ventral lateral part',
#  892: u'ansa peduncularis',
#  893: u'Supplemental somatosensory area, layer 6b',
#  894: u'Retrosplenial area, lateral agranular part',
#  895: u'Ectorhinal area',
#  896: u'thalamus related',
#  897: u'Visceral area, layer 1',
#  898: u'Pontine central gray',
#  899: u'Parabrachial nucleus, medial division, external medial part',
#  900: u'anterior commissure, olfactory limb',
#  901: u'trigeminal nerve',
#  902: u'Posterolateral visual area, layer 5',
#  903: u'External cuneate nucleus',
#  904: u'Medial septal complex',
#  905: u'Anterolateral visual area, layer 2/3',
#  906: u'Retrosplenial area, lateral agranular part, layer 6a',
#  907: u'Paracentral nucleus',
#  908: u'anterior commissure, temporal limb',
#  909: u'Entorhinal area',
#  910: u'Orbital area, medial part, layer 6a',
#  10733: u'Uvula (IX), Purkinje layer',
#  912: u'Lingula (I)',
#  913: u'Visual areas, layer 4',
#  914: u'Posterodorsal preoptic nucleus',
#  915: u'Parabrachial nucleus, medial division, medial medial part',
#  916: u'brachium of the superior colliculus',
#  10734: u'Uvula (IX), molecular layer',
#  918: u'Entorhinal area, lateral part',
#  919: u'Anterior cingulate area, dorsal part, layer 6a',
#  920: u'Central lobule',
#  182305689: u'Primary somatosensory area, unassigned',
#  922: u'Perirhinal area',
#  923: u'Parabrachial nucleus, medial division, ventral medial part',
#  924: u'cerebal peduncle',
#  182305693: u'Primary somatosensory area, unassigned, layer 1',
#  926: u'Entorhinal area, medial part, dorsal zone',
#  927: u'Anterior cingulate area, dorsal part, layer 6b',
#  928: u'Culmen',
#  929: u'Primary somatosensory area, nose, layer 6b',
#  930: u'Parafascicular nucleus',
#  931: u'Pontine gray',
#  932: u'cervicothalamic tract',
#  182305701: u'Primary somatosensory area, unassigned, layer 4',
#  934: u'Entorhinal area, medial part, ventral zone',
#  935: u'Anterior cingulate area, dorsal part, layer 1',
#  936: u'Declive (VI)',
#  182305705: u'Primary somatosensory area, unassigned, layer 5',
#  938: u'Paragigantocellular reticular nucleus',
#  939: u'Nucleus ambiguus, dorsal division',
#  940: u'cingulum bundle',
#  182305709: u'Primary somatosensory area, unassigned, layer 6a',
#  942: u'Endopiriform nucleus',
#  943: u'Primary motor area, Layer 2/3',
#  944: u'Folium-tuber vermis (VII)',
#  182305713: u'Primary somatosensory area, unassigned, layer 6b',
#  946: u'Posterior hypothalamic nucleus',
#  947: u'Somatomotor areas, Layer 6b',
#  948: u'cochlear nerve',
#  949: u'vomeronasal nerve',
#  950: u'Primary somatosensory area, mouth, layer 4',
#  560581559: u'Xiphoid thalamic nucleus',
#  952: u'Endopiriform nucleus, dorsal part',
#  953: u'Pineal body',
#  954: u'Primary auditory area, layer 6a',
#  560581563: u'Posterior intralaminar thalamic nucleus',
#  956: u'corpus callosum, anterior forceps',
#  957: u'Uvula (IX)',
#  958: u'Epithalamus',
#  959: u'Ventral auditory area, layer 1',
#  960: u'cerebellum related fiber tracts',
#  961: u'Piriform area',
#  962: u'Secondary motor area, layer 2/3',
#  963: u'Lateral reticular nucleus, parvicellular part',
#  964: u'corpus callosum, extreme capsule',
#  965: u'Retrosplenial area, lateral agranular part, layer 2/3',
#  966: u'Endopiriform nucleus, ventral part',
#  967: u'cranial nerves',
#  968: u'Nodulus (X)',
#  969: u'Orbital area, ventrolateral part, layer 1',
#  970: u'Paragigantocellular reticular nucleus, dorsal part',
#  971: u'corpus callosum, posterior forceps',
#  972: u'Prelimbic area',
#  973: u'Lateral visual area, layer 2/3',
#  974: u'Primary somatosensory area, mouth, layer 5',
#  975: u'Edinger-Westphal nucleus',
#  976: u'Lobule II',
#  977: u'Ectorhinal area/Layer 6a',
#  978: u'Paragigantocellular reticular nucleus, lateral part',
#  237: u'solitary tract',
#  980: u'Dorsal premammillary nucleus',
#  981: u'Primary somatosensory area, barrel field, layer 1',
#  982: u'Fasciola cinerea',
#  983: u'lateral forebrain bundle system',
#  984: u'Lobule III',
#  985: u'Primary motor area',
#  986: u'corpus callosum, splenium',
#  987: u'Pons, motor related',
#  988: u'Ectorhinal area/Layer 5',
#  989: u'Fastigial nucleus',
#  990: u'Ventral auditory area, layer 4',
#  991: u'medial forebrain bundle system',
#  992: u'Lobule IV',
#  993: u'Secondary motor area',
#  994: u'corticobulbar tract',
#  995: u'Paramedian reticular nucleus',
#  996: u'Agranular insular area, dorsal part, layer 1',
#  997: u'root',
#  715: u'Entorhinal area, lateral part, layer 2a',
#  999: u'Entorhinal area, lateral part, layer 2/3',
#  1000: u'extrapyramidal fiber systems',
#  1001: u'Lobule V',
#  1002: u'Primary auditory area',
#  1003: u'corticopontine tract',
#  1004: u'Ventral premammillary nucleus',
#  1005: u'Primary auditory area, layer 6b',
#  1006: u'Primary somatosensory area, trunk, layer 1',
#  1007: u'Simple lobule',
#  ...}

# %%
# name2intensity = {id2name[i]: id2intensity[i] for i in id2name.keys()}
name2intensity = {}
total_intensity = np.sum(id2intensity.values())
for i in id2intensity.keys():
    try:
        name2intensity[id2name[i]] = float(id2intensity[i]) / float(total_intensity)
    except:
        name2intensity[i] = float(id2intensity[i]) / float(total_intensity)

# %%
name2intensity
# Out:
# {u'dorsal fornix': 0.000100013933099791,
#  u'Entorhinal area, lateral part': 0.009743383665621755,
#  u'Infralimbic area, layer 2/3': 0.0001808044671244472,
#  u'Primary somatosensory area, nose, layer 2/3': 0.0011407854809137375,
#  u'Substantia nigra, reticular part': 0.003475610669339139,
#  u'Primary somatosensory area, barrel field, layer 6b': 0.00027478665760194936,
#  u'central canal, spinal cord/medulla': 1.7801861443227675e-06,
#  u'Posterior amygdalar nucleus': 0.00041060886413302964,
#  u'Orbital area, lateral part, layer 6a': 0.0006645350735398023,
#  u'Central lateral nucleus of the thalamus': 0.0003997920249985744,
#  u'Orbital area, lateral part, layer 6b': 8.045735358638064e-05,
#  u'Preparasubthalamic nucleus': 3.180092032245112e-05,
#  u'Medial vestibular nucleus': 0.0018593742851510536,
#  u'trapezoid body': 0.0003328364580843151,
#  u'Ventral auditory area, layer 6a': 0.0005592748783574984,
#  u'Medial pretectal area': 0.0001712655450265902,
#  u'Superior colliculus, motor related, intermediate white layer': 0.00478174407541978,
#  u'Retrosplenial area, ventral part, layer 5': 0.0033021635742150057,
#  u'Subparafascicular nucleus, parvicellular part': 0.0005162634920838194,
#  u'Olfactory tubercle': 0.004408122430884245,
#  u'Intermediodorsal nucleus of the thalamus': 0.00020881161154208297,
#  u'Orbital area, ventrolateral part, layer 6b': 1.4274694365169833e-05,
#  u'Globus pallidus, internal segment': 0.0010267263884967226,
#  u'fasciculus retroflexus': 0.0002729123362975139,
#  u'cingulum bundle': 0.0016547196113557959,
#  u'Dentate gyrus, polymorph layer': 0.0012285017192010677,
#  u'Secondary motor area, layer 6b': 9.644227748715936e-05,
#  u'Inferior olivary complex': 0.0007127424305090847,
#  u'Lateral vestibular nucleus': 0.00021578325505241473,
#  u'Temporal association areas, layer 1': 0.0005632485426847209,
#  u'Temporal association areas, layer 5': 0.001513983033657737,
#  u'Temporal association areas, layer 4': 0.0004555008581345077,
#  u'posteromedial visual area, layer 4': 0.00019248738197000768,
#  u'Nucleus of Roller': 2.748246985228168e-05,
#  u'Pallidum': 0.0032009328152184844,
#  u'posteromedial visual area, layer 1': 0.00023374082636665072,
#  u'Superior colliculus, superficial gray layer': 0.0035986873942858524,
#  u'Prelimbic area, layer 6a': 0.00046510860850867996,
#  u'Prelimbic area, layer 6b': 2.5362494465634357e-05,
#  u'Primary motor area, Layer 1': 0.0015743826669553814,
#  u'Nucleus prepositus': 0.00020917622409717698,
#  u'Primary motor area, Layer 5': 0.005070822352372878,
#  u'Cortical amygdalar area, anterior part': 0.0005548729312898317,
#  u'Taenia tecta': 0.0022242223393356747,
#  u'doral tegmental decussation': 6.591185944554418e-05,
#  u'amygdalar capsule': 0.00011241704639635059,
#  u'Nucleus of the posterior commissure': 0.0004231833227638354,
#  u'Infralimbic area, layer 6a': 0.0002631105127507806,
#  u'Infralimbic area, layer 6b': 1.4900274085028278e-05,
#  u'Globus pallidus, external segment': 0.004072505761769753,
#  u'midbrain tract of the trigeminal nerve': 1.7251718803733506e-05,
#  u'Uvula (IX)': 0.00217852906814084,
#  u'Parapyramidal nucleus': 4.0224082868424545e-05,
#  u'Precommissural nucleus': 0.00012218727663592283,
#  u'Hippocampal formation': 0.0035495525480849117,
#  u'Oculomotor nucleus': 6.532689969203573e-05,
#  u'Anterior cingulate area, ventral part, layer 2/3': 0.0008462731551289287,
#  u'ventricular systems': 0.00044718859454428344,
#  u'Infracerebellar nucleus': 9.845506129593865e-06,
#  u'Primary somatosensory area, upper limb, layer 2/3': 0.0017236921530277437,
#  u'Retrosplenial area, ventral part, layer 1': 0.0015965287693236038,
#  u'Ventral auditory area, layer 6b': 8.239792412164882e-05,
#  u'Frontal pole, layer 1': 0.00020844135732499592,
#  u'Anteromedial nucleus': 0.0007192709617674476,
#  u'optic nerve': 3.2122978627083214e-05,
#  u'Primary visual area, layer 1': 0.00155133389866827,
#  u'Primary visual area, layer 4': 0.0019116686232584473,
#  u'Primary visual area, layer 5': 0.002546741325967091,
#  u'Fundus of striatum': 0.0006648821163475465,
#  u'corpus callosum': 0.01605282227000719,
#  u'Central amygdalar nucleus': 0.002247834467870378,
#  u'optic chiasm': 0.00017131164546459058,
#  u'Magnocellular reticular nucleus': 0.001027027008485781,
#  u'Primary somatosensory area, upper limb, layer 6a': 0.0015126080800348582,
#  u'Superior vestibular nucleus': 0.0005046751959693997,
#  u'Superior colliculus, optic layer': 0.001516075767876475,
#  u'Ventral premammillary nucleus': 0.0001073414848867132,
#  u'Submedial nucleus of the thalamus': 0.00037975187445718787,
#  u'Primary somatosensory area, nose, layer 4': 0.0012399981368201721,
#  u'Intermediate reticular nucleus': 0.0035847826317570845,
#  u'Subparafascicular nucleus, magnocellular part': 0.00015559333039056935,
#  u'stria medullaris': 0.0004961901363318453,
#  u'Nucleus accumbens': 0.0073926704286915125,
#  u'habenular commissure': 8.71698030257172e-05,
#  u'middle cerebellar peduncle': 0.0009366303359903792,
#  u'Magnocellular nucleus': 0.0005430012625530179,
#  u'Retrosplenial area, dorsal part, layer 6b': 5.031621022228623e-05,
#  u'Retrosplenial area, dorsal part, layer 6a': 0.0011772459304714238,
#  u'Basolateral amygdalar nucleus, posterior part': 0.000994383546242253,
#  u'Periventricular hypothalamic nucleus, preoptic part': 0.00012175851032445068,
#  u'Anterior cingulate area, dorsal part, layer 2/3': 0.0012594384980965255,
#  u'Gustatory areas, layer 1': 0.0001951534702375827,
#  u'Gustatory areas, layer 5': 0.0008490071045307631,
#  u'Gustatory areas, layer 4': 0.0002330949366636173,
#  u'Gigantocellular reticular nucleus': 0.002878274398940668,
#  u'Ventral anterior-lateral complex of the thalamus': 0.00169530379344972,
#  u'Nucleus x': 9.283113024057633e-05,
#  u'Nucleus y': 3.4658180336419374e-05,
#  u'Anteroventral nucleus of thalamus': 0.0007909331254969986,
#  u'mammillothalamic tract': 0.0003851295066689677,
#  u'Supplemental somatosensory area, layer 2/3': 0.0033435146999593,
#  u'Red nucleus': 0.0013663489600069694,
#  u'motor root of the trigeminal nerve': 7.14674457956192e-05,
#  u'Lateral habenula': 0.00046350460340888313,
#  u'root': 2.2808433486207134e-07,
#  u'Temporal association areas, layer 2/3': 0.0008813517198790021,
#  u'internal capsule': 0.0059190352720853625,
#  u'Rostrolateral area, layer 6b': 0.001912741344988841,
#  u'vestibular nerve': 0.00034189728962584633,
#  u'Dorsal auditory area, layer 5': 0.0007447541877997334,
#  u'Dorsal auditory area, layer 4': 0.00029675496702221934,
#  u'Nodulus (X)': 0.0013364504081085763,
#  u'Dorsal auditory area, layer 1': 0.0002271363744568955,
#  u'Posterior hypothalamic nucleus': 0.0015851843541976266,
#  u'Posterior complex of the thalamus': 0.002300809351604477,
#  u'Cortical amygdalar area, posterior part': 0.002090129382800637,
#  u'Retrosplenial area, ventral part, layer 6b': 0.0001042076222447426,
#  u'Retrosplenial area, ventral part, layer 6a': 0.001216606355483883,
#  u'Periaqueductal gray': 0.007791685677428815,
#  u'Parvicellular reticular nucleus': 0.00275566061265807,
#  u'Dorsal premammillary nucleus': 0.00018344121874965834,
#  u'Ectorhinal area/Layer 2/3': 0.0005359042129560977,
#  u'Secondary motor area, layer 6a': 0.0028241473266372445,
#  u'Midbrain reticular nucleus, retrorubral area': 0.0007708181826366184,
#  u'Retrochiasmatic area': 0.0002493725822266642,
#  u'Ventral tegmental area': 0.0014174292124534578,
#  u'Cuneate nucleus': 0.00034319954640418604,
#  u'Ventral posteromedial nucleus of the thalamus, parvicellular part': 0.00025860878886100816,
#  u'Fasciola cinerea': 6.49893671145084e-05,
#  u'Triangular nucleus of septum': 0.0003511017417626865,
#  u'Interstitial nucleus of Cajal': 9.232370304188673e-05,
#  u'Ventral auditory area, layer 5': 0.001261305243454856,
#  u'Retrosplenial area, ventral part, layer 2/3': 0.001957310797114659,
#  u'Basolateral amygdalar nucleus, anterior part': 0.0012017400925611558,
#  u'Facial motor nucleus': 0.001324241690365263,
#  u'Anterior cingulate area, ventral part, 6b': 9.849020079063824e-05,
#  u'Anterior cingulate area, ventral part, 6a': 0.000601346524933477,
#  u'Ventral posterolateral nucleus of the thalamus': 0.0020192053096501203,
#  u'Primary motor area, Layer 2/3': 0.005903537304209755,
#  u'Peripeduncular nucleus': 9.79165243611159e-05,
#  u'Caudoputamen': 0.05230318391101832,
#  u'Basic cell groups and regions': 0.00012091193864480714,
#  u'Lateral visual area, layer 2/3': 0.000454184416606014,
#  u'Bed nucleus of the anterior commissure': 2.0069809564435692e-05,
#  u'Agranular insular area, posterior part, layer 1': 0.0004222821075580306,
#  u'Paragigantocellular reticular nucleus, lateral part': 0.0009237934594817251,
#  u'Agranular insular area, posterior part, layer 5': 0.0011055942441141457,
#  u'Intergeniculate leaflet of the lateral geniculate complex': 0.00017377560104247158,
#  u'Lingula (I)': 0.0001485791326297757,
#  u'Postsubiculum': 0.0011750637356125102,
#  u'Nucleus of the brachium of the inferior colliculus': 0.0002511840392974628,
#  u'Midbrain': 0.009799485642003433,
#  u'Rhomboid nucleus': 0.00012484917395458873,
#  u'Lateral septal nucleus, caudal (caudodorsal) part': 0.0008577052578013123,
#  u'Nucleus ambiguus, dorsal division': 2.5632327099245037e-05,
#  u'Anterolateral visual area, layer 4': 0.00021734728494723218,
#  u'Anterolateral visual area, layer 5': 0.0003734757672754284,
#  u'Anterolateral visual area, layer 1': 0.0001274269299143868,
#  u'posteromedial visual area, layer 5': 0.0005271069276248134,
#  u'third ventricle': 0.0019731579032724648,
#  u'Dorsal cochlear nucleus': 0.0006791247338345272,
#  u'Agranular insular area, ventral part, layer 1': 0.000257525428567999,
#  526322272: 7.379293886915637e-07,
#  u'Spinal nucleus of the trigeminal, oral part': 0.0007302968647763312,
#  u'Medullary reticular nucleus, dorsal part': 0.00041333975091835347,
#  u'Infralimbic area, layer 1': 0.0001847159119794034,
#  u'Posterior limiting nucleus of the thalamus': 0.00023240165699984217,
#  u'Infralimbic area, layer 5': 0.0004144501911889293,
#  u'Ventral posterolateral nucleus of the thalamus, parvicellular part': 8.166080068467056e-05,
#  u'Parasubthalamic nucleus': 0.00014967651648259617,
#  u'Anterodorsal nucleus': 0.0002684549397519727,
#  u'Septohippocampal nucleus': 5.6744319897172836e-05,
#  u'fimbria': 0.0028009746029766286,
#  u'Midbrain reticular nucleus': 0.009155371611784719,
#  u'Interanterodorsal nucleus of the thalamus': 0.00015917997670506827,
#  u'Primary somatosensory area, lower limb, layer 4': 0.0005301737350842379,
#  u'Primary somatosensory area, lower limb, layer 5': 0.0009683806425452356,
#  u'Primary auditory area, layer 1': 0.0004319033979209862,
#  u'Primary auditory area, layer 5': 0.0015019398583963344,
#  u'Primary auditory area, layer 4': 0.0005094606148622514,
#  u'Primary somatosensory area, barrel field, layer 6a': 0.0024656393722004184,
#  u'Accessory supraoptic group': 2.9183511538359025e-06,
#  u'Medullary reticular nucleus, ventral part': 0.0009951427527561754,
#  u'Pontine reticular nucleus': 0.004489314006481436,
#  u'Dorsal motor nucleus of the vagus nerve': 0.00010394858936409006,
#  u'Interfascicular nucleus raphe': 4.995401552233212e-05,
#  u'Lateral visual area, layer 6a': 0.0003090034987801692,
#  u'Lateral visual area, layer 6b': 6.510623011293596e-05,
#  u'Laterodorsal tegmental nucleus': 0.00018560939004876062,
#  u'Prelimbic area, layer 5': 0.0010786187178895258,
#  u'Prelimbic area, layer 1': 0.0005683431246547919,
#  u'Prelimbic area, layer 2/3': 0.00046830710847805667,
#  u'Posterolateral visual area, layer 1': 0.00021369954749286563,
#  u'Posterolateral visual area, layer 4': 0.0001092011378699667,
#  u'Posterolateral visual area, layer 5': 0.0003432480646973263,
#  u'internal medullary lamina of the thalamus': 3.501215432889789e-06,
#  u'Interpeduncular nucleus': 0.0007599512133055964,
#  u'Trochlear nucleus': 1.1798488321246767e-05,
#  u'Dorsomedial nucleus of the hypothalamus': 0.0009900628391072864,
#  u'Anterior tegmental nucleus': 2.5002395240134805e-05,
#  u'Subparaventricular zone': 0.00023307527144181292,
#  u'Posterolateral visual area, layer 2/3': 0.0002916100936652387,
#  u'Lateral septal nucleus, ventral part': 0.00026951009173501654,
#  u'Motor nucleus of trigeminal': 0.0006543526795940518,
#  u'Abducens nucleus': 2.342998344749911e-05,
#  u'Dorsal nucleus raphe': 0.0002050581332229323,
#  u'trochlear nerve': 1.186812254927533e-05,
#  u'Primary somatosensory area, lower limb, layer 1': 0.0003391462540476902,
#  u'Gracile nucleus': 5.677526844296331e-05,
#  u'Nucleus of the solitary tract': 0.0006386598325941707,
#  u'Ventrolateral preoptic nucleus': 2.7181205101852558e-05,
#  u'Primary visual area, layer 6b': 0.00027165908138334244,
#  u'Primary visual area, layer 6a': 0.0015167498658894738,
#  u'Subgeniculate nucleus': 7.450572256439317e-05,
#  u'Retrosplenial area, dorsal part, layer 2/3': 0.0015036263929515724,
#  u'Paramedian lobule': 0.00489260902000667,
#  u'Anterior olfactory nucleus': 0.004389641474527397,
#  u'Piriform area': 0.014123307941532314,
#  u'Subparafascicular area': 7.301761332096798e-05,
#  u'Supplemental somatosensory area, layer 6b': 0.0003607691325636425,
#  u'Posterolateral visual area, layer 6b': 7.697806004009243e-06,
#  u'Secondary motor area, layer 1': 0.002612247630510506,
#  u'Supraoptic nucleus': 6.019153656527196e-05,
#  u'Lateral reticular nucleus': 0.0005389212125996407,
#  u'Nucleus raphe pallidus': 4.80811449309806e-05,
#  u'Agranular insular area, dorsal part, layer 6a': 0.001144440794314209,
#  u'Ventral cochlear nucleus': 0.0008368855907628283,
#  u'Primary somatosensory area, barrel field, layer 2/3': 0.0027689164228672943,
#  u"Barrington's nucleus": 5.446154226444022e-05,
#  u'cuneate fascicle': 2.252957419340757e-05,
#  u'Agranular insular area, ventral part, layer 2/3': 0.0006844933393871182,
#  u'Paraventricular hypothalamic nucleus, descending division': 0.00011879212444850247,
#  u'inferior cerebellar peduncle': 0.0008366499304818612,
#  u'Posterodorsal preoptic nucleus': 6.243063161514407e-06,
#  u'Lateral mammillary nucleus': 4.60875427729777e-05,
#  u'Nucleus ambiguus, ventral division': 2.8021973929160377e-05,
#  u'vomeronasal nerve': 1.718289052741824e-07,
#  u'Spinal nucleus of the trigeminal, caudal part': 0.0014604483358635844,
#  u'Visceral area, layer 6b': 7.513678275590201e-05,
#  u'Visceral area, layer 6a': 0.0008271187455204519,
#  u'Retrosplenial area, dorsal part, layer 5': 0.0020278705800907673,
#  u'Parabigeminal nucleus': 0.00015738238200373837,
#  u'Retrosplenial area, dorsal part, layer 1': 0.0010409496631425842,
#  u'Paraventricular hypothalamic nucleus': 0.000625083092412713,
#  u'Lateral amygdalar nucleus': 0.0010895954578438985,
#  u'Inferior colliculus': 0.011530041924582955,
#  u'Superior olivary complex, periolivary region': 0.00018987577603825129,
#  182305696: 0.0012332829471450102,
#  u'fourth ventricle': 0.0009803751383231554,
#  u'Suprageniculate nucleus': 6.694831334883967e-05,
#  u'Medial preoptic area': 0.0013078966672389848,
#  u'Paraflocculus': 0.0034154217118193496,
#  182305712: 0.001077835977585575,
#  u'Anteromedial visual area, layer 6b': 5.3596594885733596e-05,
#  u'Anteromedial visual area, layer 6a': 0.00021723654718182564,
#  u'Septofimbrial nucleus': 0.00045703667971935986,
#  u'Pontine gray': 0.0012351909572310615,
#  u'Inferior salivatory nucleus': 9.78006285047443e-06,
#  312782560: 0.002610149254629775,
#  u'external medullary lamina of the thalamus': 0.00040602993006912374,
#  u'Ectorhinal area/Layer 6b': 6.995370728771127e-05,
#  u'Ectorhinal area/Layer 6a': 0.0005150900263892641,
#  u'arbor vitae': 0.007992401826391549,
#  u'alveus': 0.0010079644773726196,
#  u'Posterior auditory area, layer 1': 0.00011704643303750867,
#  u'Posterior auditory area, layer 4': 0.00012117048795443171,
#  u'Posterior auditory area, layer 5': 0.000297659083654192,
#  u'Secondary motor area, layer 5': 0.005987922060495016,
#  u'External cuneate nucleus': 9.840928323862357e-05,
#  u'Agranular insular area, dorsal part, layer 5': 0.0017775010355947588,
#  u'Zona incerta': 0.003997210206526333,
#  u'Nucleus raphe obscurus': 1.916827197794554e-05,
#  u'Agranular insular area, dorsal part, layer 1': 0.0004764883243196994,
#  u'Agranular insular area, dorsal part, layer 2/3': 0.0010575548474819137,
#  u'Frontal pole, layer 2/3': 0.00019338440622690338,
#  u'Superior olivary complex, lateral part': 0.0002933354750930575,
#  u'Median preoptic nucleus': 0.00029479118507760827,
#  u'rubrospinal tract': 0.0005111721339206016,
#  u'Anterior cingulate area, dorsal part, layer 5': 0.002206142263361018,
#  u'optic tract': 0.0008147149874625217,
#  u'Ventromedial hypothalamic nucleus': 0.0006190449021767178,
#  u'Nucleus raphe pontis': 6.59621508324537e-05,
#  u'dorsal hippocampal commissure': 0.0012729497949988636,
#  u'Superior colliculus, motor related, deep gray layer': 0.0026349872357203977,
#  u'Dentate gyrus, granule cell layer': 0.002457777152046897,
#  u'Pyramus (VIII)': 0.0008832476406893538,
#  u'Nucleus incertus': 0.000204470272043256,
#  u'Endopiriform nucleus, dorsal part': 0.0027272827304523194,
#  u'Superior olivary complex, medial part': 0.00025646108873542356,
#  u'Nucleus of the trapezoid body': 0.00014000783615889892,
#  u'Agranular insular area, dorsal part, layer 6b': 8.908958000678242e-05,
#  u'mammillotegmental tract': 0.00014340911357934032,
#  u'Dorsal peduncular area': 0.0003575240485852374,
#  u'Entorhinal area, medial part, ventral zone': 0.0002910494736534717,
#  u'Superior central nucleus raphe': 0.0010821811856526259,
#  u'Parafascicular nucleus': 0.0006866416842740735,
#  u'Primary visual area, layer 2/3': 0.0033749123220444192,
#  u'Basomedial amygdalar nucleus': 0.0014127572715618378,
#  u'Striatum': 0.004983942047202576,
#  u'Culmen': 0.009785206756689355,
#  u'principal mammillary tract': 9.761687151411337e-07,
#  u'Hypoglossal nucleus': 0.00041908183449488457,
#  u'Bed nucleus of the accessory olfactory tract': 7.702996333042854e-05,
#  u'Pontine central gray': 0.0009238642220421523,
#  527696992: 3.1852823612787222e-06,
#  u'Anterior pretectal nucleus': 0.002430046932637949,
#  u'Presubiculum': 0.0014448204485717946,
#  u'Retrosplenial area, lateral agranular part, layer 2/3': 0.0009298883887183362,
#  u'Supplemental somatosensory area, layer 4': 0.0023064250619523638,
#  u'Supplemental somatosensory area, layer 5': 0.004453706737407442,
#  u'Supplemental somatosensory area, layer 1': 0.0013808175663543576,
#  u'Ectorhinal area/Layer 1': 0.00023988040532817823,
#  u'Periventricular hypothalamic nucleus, posterior part': 0.00013698471128233486,
#  u'Ectorhinal area/Layer 5': 0.0006556512289945104,
#  u'Nucleus of the optic tract': 0.00017006225911864295,
#  u'Agranular insular area, posterior part, layer 6b': 4.272076008586527e-05,
#  u'Agranular insular area, posterior part, layer 6a': 0.0006364678051243548,
#  u'mammillary peduncle': 3.218068476975503e-05,
#  u'anterior commissure, temporal limb': 0.00044899021900417983,
#  u'supramammillary decussation': 2.6984875264494252e-05,
#  u'Primary somatosensory area, trunk, layer 6b': 6.213742638184788e-05,
#  u'posteromedial visual area, layer 2/3': 0.0004832520322880014,
#  u'Interanteromedial nucleus of the thalamus': 9.260691447393808e-05,
#  u'anterior commissure, olfactory limb': 0.001346348784670562,
#  u'Perireunensis nucleus': 4.4860400694316954e-05,
#  u'Parastrial nucleus': 5.633038309722528e-05,
#  u'Thalamus': 0.010207122317408179,
#  u'Anterior cingulate area, dorsal part, layer 6b': 4.2061813965076475e-05,
#  u'Anterior cingulate area, dorsal part, layer 6a': 0.00108655024989039,
#  u'Spinal vestibular nucleus': 0.0009627887883680624,
#  u'Field CA1': 0.014992011699984258,
#  u'Temporal association areas, layer 6b': 0.00014479389981312128,
#  u'Anteroventral periventricular nucleus': 7.37748855507786e-05,
#  u'Temporal association areas, layer 6a': 0.0008520408679699426,
#  u'tectospinal pathway': 0.00026654386704941105,
#  u'Ansiform lobule': 0.012966484343904721,
#  u'Field CA3': 0.010617255508840023,
#  u'Primary somatosensory area, trunk, layer 6a': 0.00040081493891308654,
#  u'ventral tegmental decussation': 9.513776404402245e-05,
#  u'Primary somatosensory area, trunk, layer 2/3': 0.000692511108221305,
#  u'Supragenual nucleus': 2.1671880380120587e-05,
#  u'Superior colliculus, motor related, intermediate gray layer, sublayer a': 0.0002730532166569976,
#  u'Arcuate hypothalamic nucleus': 0.00021635403005576922,
#  u'Superior colliculus, motor related, intermediate gray layer, sublayer c': 0.00013057014159623158,
#  u'Superior colliculus, motor related, intermediate gray layer, sublayer b': 0.0007644975869202852,
#  u'Midbrain trigeminal nucleus': 5.3916074144883155e-05,
#  u'Lateral dorsal nucleus of thalamus': 0.0019681737366871147,
#  u'cerebal peduncle': 0.0015410156212636583,
#  u'Subiculum': 0.0069271488505249414,
#  u'Substantia nigra, compact part': 0.0003712829338538994,
#  u'cerebral aqueduct': 0.0006922006556213443,
#  u'columns of the fornix': 0.0006068916339112792,
#  u'Lateral septal nucleus, rostral (rostroventral) part': 0.004008345396587539,
#  u'Nucleus of Darkschewitsch': 5.654782886947187e-05,
#  u'Agranular insular area, ventral part, layer 6a': 0.0005030958529920296,
#  u'Perirhinal area, layer 6b': 4.9384207661033585e-05,
#  u'Perirhinal area, layer 6a': 0.0002593336618319444,
#  u'posteromedial visual area, layer 6a': 0.00023733649934033852,
#  u'posteromedial visual area, layer 6b': 4.610398418792888e-05,
#  u'Induseum griseum': 3.3076419503909474e-05,
#  u'Accessory facial motor nucleus': 8.705568026311484e-06,
#  u'Pontine reticular nucleus, caudal part': 0.005168967283449542,
#  u'stria terminalis': 0.0016092993966014253,
#  u'medial lemniscus': 0.0009306010112232303,
#  u'Reticular nucleus of the thalamus': 0.004032664183584458,
#  u'Posterior auditory area, layer 6b': 3.105638212971055e-05,
#  u'Posterior auditory area, layer 6a': 0.00013677613097893448,
#  u'Medial geniculate complex': 0.0009757860492676619,
#  u'Fastigial nucleus': 0.0005709339370323453,
#  u'Gustatory areas, layer 6b': 5.860413407076901e-05,
#  u'Gustatory areas, layer 6a': 0.0006456487234711668,
#  u'Edinger-Westphal nucleus': 5.482792791330346e-05,
#  u'Primary somatosensory area, lower limb, layer 6a': 0.000998136379800033,
#  u'Primary somatosensory area, lower limb, layer 6b': 9.791072150878019e-05,
#  u'Orbital area, medial part, layer 6a': 0.00019385459845643884,
#  u'Copula pyramidis': 0.0025292142940580966,
#  u'brachium of the inferior colliculus': 0.0005444656768160722,
#  u'Lateral visual area, layer 1': 0.00020431907550184214,
#  u'Lateral visual area, layer 5': 0.0005062730758361753,
#  u'Lateral visual area, layer 4': 0.0003059001011129611,
#  u'Cortical subplate': 0.0025753598653544315,
#  u'Claustrum': 0.000770516595505504,
#  u'Ventral posteromedial nucleus of the thalamus': 0.004381443978461146,
#  u'Vascular organ of the lamina terminalis': 9.347427970778457e-06,
#  u'Ventral auditory area, layer 2/3': 0.0006460634662228277,
#  u'Nucleus sagulum': 0.00016775739840896607,
#  u'Paragigantocellular reticular nucleus, dorsal part': 0.00018133204311596916,
#  u'Area postrema': 4.3191274696086035e-05,
#  u'Lateral preoptic area': 0.0018511284319820047,
#  u'Folium-tuber vermis (VII)': 0.0009623753351391427,
#  u'Bed nuclei of the stria terminalis': 0.0035314972954230248,
#  u'Anterior cingulate area, dorsal part, layer 1': 0.0011325789581882973,
#  526157184: 0.0004076281323165848,
#  u'Nucleus of the lateral lemniscus': 0.0010573723800140242,
#  u'Primary somatosensory area, upper limb, layer 6b': 0.00012103009116597597,
#  u'pyramid': 0.0005854646016616572,
#  u'Medial septal nucleus': 0.0012473472881130104,
#  u'Medial preoptic nucleus': 0.0002981568394323221,
#  u'Orbital area, ventrolateral part, layer 1': 0.00040738312299574357,
#  u'Primary auditory area, layer 2/3': 0.0008123164751637601,
#  u'Orbital area, ventrolateral part, layer 5': 0.000661719884205268,
#  u'Subceruleus nucleus': 5.217537963451177e-05,
#  u'Interposed nucleus': 0.0009615384348800587,
#  u'Orbital area, lateral part, layer 1': 0.00037875007647756405,
#  u'Orbital area, lateral part, layer 5': 0.0015180295560198412,
#  u'lateral recess': 0.0009369472362040463,
#  u'Ventral auditory area, layer 4': 0.0004680408220319845,
#  u'Ventral auditory area, layer 1': 0.0003747644840649848,
#  u'Anteromedial visual area, layer 1': 0.00016066260547684306,
#  u'Tegmental reticular nucleus': 0.0012473887140310737,
#  u'Posterior auditory area, layer 2/3': 0.0002103280902858161,
#  u'Anterodorsal preoptic nucleus': 6.974399865191229e-05,
#  u'Agranular insular area, ventral part, layer 5': 0.0011222219951014475,
#  u'Central medial nucleus of the thalamus': 0.0002940658285356441,
#  u'Agranular insular area, posterior part, layer 2/3': 0.0009666931408479415,
#  u'Dorsal tegmental nucleus': 0.00012724881458574892,
#  u'Primary somatosensory area, upper limb, layer 1': 0.0005418508470774627,
#  u'Orbital area, lateral part, layer 2/3': 0.0007153350159804073,
#  u'Orbital area, medial part, layer 1': 0.00046406844722750334,
#  u'Primary somatosensory area, upper limb, layer 5': 0.0014186347550262024,
#  u'Primary somatosensory area, upper limb, layer 4': 0.0010423792602916244,
#  u'Supramammillary nucleus': 0.00040989978781567394,
#  u'Orbital area, medial part, layer 5': 0.0004853852252827468,
#  u'Perirhinal area, layer 1': 0.0002801533288704284,
#  u'Posterolateral visual area, layer 6a': 0.00010322323282212587,
#  u'Perirhinal area, layer 5': 0.000593298613505213,
#  u'Suprachiasmatic nucleus': 8.675054694446191e-05,
#  u'Agranular insular area, ventral part, layer 6b': 1.2286733869159993e-05,
#  u'Dorsal part of the lateral geniculate complex': 0.0014763149460528516,
#  u'Nucleus raphe magnus': 0.00019831666952191719,
#  u'spinal tract of the trigeminal nerve': 0.0015792080610532125,
#  u'Lateral terminal nucleus of the accessory optic tract': 1.1714991723749556e-05,
#  u'Subfornical organ': 3.268375982919286e-05,
#  u'Anterolateral visual area, layer 6a': 0.00018641824318822202,
#  u'Anterolateral visual area, layer 6b': 4.758516224661975e-05,
#  u'Endopiriform nucleus, ventral part': 0.0006001142247638512,
#  u'Medial amygdalar nucleus': 0.002171582570323963,
#  u'Gustatory areas, layer 2/3': 0.0005055575519051134,
#  u'Locus ceruleus': 2.343046701852709e-05,
#  u'Supratrigeminal nucleus': 0.0002845373838100599,
#  u'lateral lemniscus': 0.0015452491244232465,
#  u'Orbital area, ventrolateral part, layer 2/3': 0.0005803418113816208,
#  u'Substantia innominata': 0.005411538116787036,
#  u'Sublaterodorsal nucleus': 0.00011932808233784267,
#  u'Retrosplenial area, lateral agranular part, layer 6b': 5.7596372048466764e-05,
#  u'Retrosplenial area, lateral agranular part, layer 6a': 0.0005953413787177269,
#  u'Medulla': 0.01153571695297694,
#  u'Postpiriform transition area': 0.0012076736702647654,
#  u'Cuneiform nucleus': 0.00046540842254602513,
#  u'Parabrachial nucleus': 0.00136708866248943,
#  u'Primary auditory area, layer 6a': 0.0005722339371458878,
#  u'Primary auditory area, layer 6b': 0.00010282944481501066,
#  u'Rostral linear nucleus raphe': 1.3729709816640744e-05,
#  u'Ventral medial nucleus of the thalamus': 0.0018853198050860845,
#  u'posterior commissure': 8.291921368980708e-05,
#  u'Striatum-like amygdalar nuclei': 0.0003743386191796805,
#  'background': 0.2557132537166046,
#  u'Flocculus': 0.001106864585204639,
#  u'gracile fascicle': 2.610316409015112e-06,
#  u'facial nerve': 0.00014896179850324746,
#  u'medial longitudinal fascicle': 0.0014250241790188507,
#  u'Posterior pretectal nucleus': 0.00014062422802922582,
#  u'Lateral posterior nucleus of the thalamus': 0.002023434299480114,
#  u'Entorhinal area, medial part, dorsal zone': 0.0032830862135903196,
#  u'Pedunculopontine nucleus': 0.0007985498527586505,
#  u'Nucleus of the lateral olfactory tract, layer 3': 0.00027391929236810284,
#  u'Anterior cingulate area, ventral part, layer 5': 0.0015398007296510395,
#  u'Principal sensory nucleus of the trigeminal': 0.0018360713196935695,
#  u'Declive (VI)': 0.004376805242780113,
#  u'Parataenial nucleus': 0.0005492490002344694,
#  u'Superior colliculus, motor related, deep white layer': 0.0007154347928025131,
#  u'Periventricular hypothalamic nucleus, intermediate part': 0.00019349804541847777,
#  u'Primary somatosensory area, trunk, layer 4': 0.0003181115590920995,
#  u'Primary somatosensory area, trunk, layer 5': 0.0006581519359705175,
#  u'Subthalamic nucleus': 0.0005495534887917517,
#  u'Olivary pretectal nucleus': 0.00014872662179330842,
#  u'Lateral hypothalamic area': 0.006729535293277702,
#  u'Orbital area, ventrolateral part, layer 6a': 0.00026655950251264893,
#  u'Medial habenula': 0.00037988920862913313,
#  u'Paracentral nucleus': 0.00046048824852671077,
#  u'Medial mammillary nucleus': 0.0009613063207866302,
#  u'Primary somatosensory area, mouth, layer 1': 0.000890472191847317,
#  u'Intercalated amygdalar nucleus': 0.0002770712083284512,
#  u'Primary somatosensory area, mouth, layer 5': 0.0022174992513337224,
#  u'Primary somatosensory area, mouth, layer 4': 0.0017749111903592612,
#  u'Visceral area, layer 1': 0.00035842606974275553,
#  u'Visceral area, layer 5': 0.0011254540226620971,
#  u'Visceral area, layer 4': 0.0002872419965695304,
#  u'inferior colliculus commissure': 4.666089682181472e-05,
#  u'Primary somatosensory area, nose, layer 5': 0.0012391662334617106,
#  u'Anterior cingulate area, ventral part, layer 1': 0.0006937358324448259,
#  u'Primary somatosensory area, nose, layer 1': 0.00048851924911506,
#  u'Primary somatosensory area, lower limb, layer 2/3': 0.0010869683776392467,
#  u'Basolateral amygdalar nucleus, ventral part': 0.0003193493397333757,
#  u'Anteromedial visual area, layer 2/3': 0.0003393421003140205,
#  u'Linear nucleus of the medulla': 3.6829253061689506e-05,
#  u'Pons': 0.008787726099203256,
#  u'Primary motor area, Layer 6b': 0.0002965866843044836,
#  u'Primary motor area, Layer 6a': 0.004005791174417768,
#  u'Mediodorsal nucleus of thalamus': 0.0020471710281496926,
#  312782592: 0.001467854064966696,
#  u'Visceral area, layer 2/3': 0.0006834747776118578,
#  u'Anterior amygdalar area': 0.0008682135786199187,
#  u'Orbital area, medial part, layer 2/3': 0.000347331660838242,
#  u'Secondary motor area, layer 2/3': 0.004997960126542233,
#  u'Supplemental somatosensory area, layer 6a': 0.004093449545372084,
#  u'corticospinal tract': 0.00010405158999304897,
#  u'Perirhinal area, layer 2/3': 0.0006152649886413712,
#  u'lateral ventricle': 0.004477338692354293,
#  u'Diagonal band nucleus': 0.0015827734302424803,
#  312782656: 0.001031302743515146,
#  u'Nucleus of reuniens': 0.0009294955678532769,
#  u'fiber tracts': 0.006724358665423217,
#  u'Simple lobule': 0.006967935326498902,
#  u'Primary somatosensory area, barrel field, layer 1': 0.0009540759667763312,
#  u'Primary somatosensory area, barrel field, layer 5': 0.0024624956769475456,
#  u'Primary somatosensory area, barrel field, layer 4': 0.0028759485834864455,
#  u'Retrosplenial area, lateral agranular part, layer 5': 0.0011510350912323768,
#  u'Anteroventral preoptic nucleus': 7.18738066494618e-05,
#  u'Retrosplenial area, lateral agranular part, layer 1': 0.0005826421587617032,
#  u'Spinal nucleus of the trigeminal, interpolar part': 0.0014295144583942943,
#  u'Paraventricular nucleus of the thalamus': 0.0006229047661220232,
#  u'Field CA2': 0.0027155587120693808,
#  u'Primary somatosensory area, mouth, layer 2/3': 0.0023001073676621984,
#  u'Dentate gyrus, molecular layer': 0.006264350441736944,
#  u'Superior colliculus, motor related, intermediate gray layer': 0.004514318013624998,
#  u'Ventral part of the lateral geniculate complex': 0.0011730902822473398,
#  u'Dentate nucleus': 0.00035013556684879025,
#  u'Central linear nucleus raphe': 0.00012876642166188064,
#  u'Anteromedial visual area, layer 4': 0.0001143450440848914,
#  u'Anteromedial visual area, layer 5': 0.0004198964904866817,
#  u'Tuberal nucleus': 0.00046687074133462496,
#  u'Periventricular hypothalamic nucleus, anterior part': 1.6886300296926215e-05,
#  u'Primary somatosensory area, mouth, layer 6a': 0.0026975838933884803,
#  u'Primary somatosensory area, mouth, layer 6b': 0.00017579434889392924,
#  u'Ventral tegmental nucleus': 5.4290358120536674e-05,
#  u'Tuberomammillary nucleus, ventral part': 2.879971733248864e-05,
#  u'solitary tract': 1.2617980023323637e-05,
#  u'Fields of Forel': 0.0001330684307170989,
#  u'Anterior hypothalamic nucleus': 0.0014438966667180177,
#  u'Central lobule': 0.005357178446819157,
#  u'Dorsal auditory area, layer 2/3': 0.0005947062887676516,
#  u'Tuberomammillary nucleus, dorsal part': 2.1697187263918005e-05,
#  u'Piriform-amygdalar area': 0.0007014165522725133,
#  u'Parasolitary nucleus': 1.4384464988520413e-05,
#  u'Primary somatosensory area, nose, layer 6b': 9.517096925461014e-05,
#  u'Primary somatosensory area, nose, layer 6a': 0.0014543825820789945,
#  u'Nucleus of the lateral olfactory tract, molecular layer': 0.0001593582532240488,
#  u'superior cerebelar peduncles': 0.0006625229344923936,
#  u'Dorsal auditory area, layer 6b': 6.092124524648793e-05,
#  u'Dorsal auditory area, layer 6a': 0.00037974236422697104,
#  u'ventral hippocampal commissure': 0.00017876315262501733,
#  u'Parasubiculum': 0.001079777998833927,
#  u'Hypothalamus': 0.006037426677342015,
#  u'Primary somatosensory area, trunk, layer 1': 0.00021836471839009394,
#  u'Anterolateral visual area, layer 2/3': 0.0003438752563206113}

# %%
max_val = 0.0
for i in name2intensity.iteritems():
    if i[1] > max_val: 
        max_val = i[1]
        max_region = i[0]
    
print('Region with most intensity: {}, Intensity: {}'.format(max_region, max_val))
# Out:
# Region with most intensity: background, Intensity: 0.255713253717

# %%
# Top 5 intensity regions
sorted_vals = np.sort(name2intensity.values())
for key, value in name2intensity.items():
    if np.isin(value, sorted_vals[-5:]):
        print('Region: {}; Intensity: {}'.format(key, value))
# Out:
# Region: corpus callosum; Intensity: 0.01605282227
# Region: Caudoputamen; Intensity: 0.052303183911
# Region: Piriform area; Intensity: 0.0141233079415
# Region: Field CA1; Intensity: 0.0149920117
# Region: background; Intensity: 0.255713253717
