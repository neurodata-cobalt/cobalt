# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import animation
import matplotlib.mlab as mlab
import glob

# %%
a = np.random.rand(2,3)
print(a)
a = a - 1
print(a)
# Out:
# [[ 0.6157957   0.200338    0.9025364 ]
#  [ 0.93129471  0.85237234  0.16568884]]
# [[-0.3842043  -0.799662   -0.0974636 ]
#  [-0.06870529 -0.14762766 -0.83431116]]

# %%
a = plt.imread('../mount/ndpull_download/ailey-dev_DRN-BLA_2378_2p_glycerol_Ch0_x0-11628_y0-7074_z116.tif')

# %%
tifList = glob.glob('/run/mount/ndpull_download/*.tif')
if tifList:
    data_cutout = plt.imread(tifList[0])
    if len(tifList)>1:
        for tifFile in tifList:
            data_cutout = np.dstack((data_cutout, plt.imread(tifFile)))

# %%
print(data_cutout.shape)
# Out:
# (7074, 11628, 3)

# %%
plot_data()

# %%
# Initialize for download
from bossHandler import bossHandler
from intern.resource.boss.resource import *
from intern.remote.boss import BossRemote
from skimage import filters
import numpy as np

import matplotlib.pyplot as plt
from matplotlib import animation
import matplotlib.mlab as mlab


coll_name = 'ailey-dev'
exp_name = 'Insula_Atenolol-1_171204_new'
chan_name = 'Ch0'

bHandler = bossHandler(coll_name)
# bHandler.list_experiments()
bHandler.select_experiment(exp_name)
exp = bHandler.get_experiment()
bHandler.list_channels()
bHandler.select_channel(chan_name)
coor = bHandler.get_coordinate_frame()
# Out:
# HTTPErrorTraceback (most recent call last)
# <ipython-input-10-21378ff99cf9> in <module>()
#      17 bHandler = bossHandler(coll_name)
#      18 # bHandler.list_experiments()
# ---> 19 bHandler.select_experiment(exp_name)
#      20 exp = bHandler.get_experiment()
#      21 bHandler.list_channels()
#
# /run/tractography/bossHandler.pyc in select_experiment(self, experiment_name)
#      29         """
#      30         tmp = ExperimentResource(collection_name = self.collection_name, name = experiment_name)
# ---> 31         exp = self.rmt.get_project(tmp)
#      32         self.experiment = exp
#      33 #         return exp
#
# /usr/local/lib/python2.7/dist-packages/intern-0.9.5-py2.7.egg/intern/remote/boss/remote.pyc in get_project(self, resource)
#     732         """
#     733         self.project_service.set_auth(self._token_project)
# --> 734         return self.project_service.get(resource)
#     735
#     736     def update_project(self, resource_name, resource):
#
# /usr/local/lib/python2.7/dist-packages/intern-0.9.5-py2.7.egg/intern/service/boss/project.pyc in get(self, resource)
#     432         return self.service.get(
#     433             resource, self.url_prefix, self.auth, self.session,
# --> 434             self.session_send_opts)
#     435
#     436     def update(self, resource_name, resource):
#
# /usr/local/lib/python2.7/dist-packages/intern-0.9.5-py2.7.egg/intern/service/boss/v1/project.pyc in get(self, resource, url_prefix, auth, session, send_opts)
#     792         err = ('Get failed on {}, got HTTP response: ({}) - {}'.format(
#     793             resource.name, resp.status_code, resp.text))
# --> 794         raise HTTPError(err, request = req, response = resp)
#     795
#     796     def update(self, resource_name, resource, url_prefix, auth, session, send_opts):
#
# HTTPError: Get failed on Insula_Atenolol-1_171204_new, got HTTP response: (500) - <h1>Server Error (500)</h1>

# %%
x = np.linspace(0, 2*np.pi, 400)
y = np.sin(x**2)
f, (ax1, ax2) = plt.subplots(1, 2, sharey=True)
ax1.plot(x, y)
ax1.set_title('Sharing Y axis')
ax2.scatter(x, y)
